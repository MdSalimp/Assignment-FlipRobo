# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('cause_of_deaths dataset.csv')

# %%
data.head()
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# ...

# %%
data.shape
# Out:
# (6120, 34)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country/Territory                           6120 non-null   object
#  1   Code                                        6120 non-null   object
#  2   Year                                        6120 non-null   int64
#  3   Meningitis                                  6120 non-null   int64
#  4   Alzheimer's Disease and Other Dementias     6120 non-null   int64
#  5   Parkinson's Disease                         6120 non-null   int64
#  6   Nutritional Deficiencies                    6120 non-null   int64
#  7   Malaria                                     6120 non-null   int64
#  8   Drowning                                    6120 non-null   int64
#  9   Interpersonal Violence                      6120 non-null   int64
# ...

# %%
data.describe().T
# Out:
#                                              count          mean  \
# Year                                        6120.0   2004.500000
# Meningitis                                  6120.0   1719.701307
# Alzheimer's Disease and Other Dementias     6120.0   4864.189379
# Parkinson's Disease                         6120.0   1173.169118
# Nutritional Deficiencies                    6120.0   2253.600000
# Malaria                                     6120.0   4140.960131
# Drowning                                    6120.0   1683.333170
# Interpersonal Violence                      6120.0   2083.797222
# Maternal Disorders                          6120.0   1262.589216
# HIV/AIDS                                    6120.0   5941.898529
# Drug Use Disorders                          6120.0    434.006699
# Tuberculosis                                6120.0   7491.928595
# Cardiovascular Diseases                     6120.0  73160.454575
# ...

# %%
data.isna().sum()
# Out:
# Country/Territory                             0
# Code                                          0
# Year                                          0
# Meningitis                                    0
# Alzheimer's Disease and Other Dementias       0
# Parkinson's Disease                           0
# Nutritional Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal Violence                        0
# Maternal Disorders                            0
# HIV/AIDS                                      0
# Drug Use Disorders                            0
# Tuberculosis                                  0
# Cardiovascular Diseases                       0
# Lower Respiratory Infections                  0
# Neonatal Disorders                            0
# Alcohol Use Disorders                         0
# Self-harm                                     0
# Exposure to Forces of Nature                  0
# ...

# %%
data['Country/Territory'].nunique()
# Out:
# 204

# %%
data['Code'].nunique()
# Out:
# 204

# %%
plt.figure(figsize=(50,30),facecolor='lightblue')
sns.countplot(data[data.columns[0]], color = 'green')
plt.xlabel(data.columns[0],fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=25)
plt.show()

# %%
data['Country/Territory'].value_counts()
# Out:
# Afghanistan         30
# Papua New Guinea    30
# Niue                30
# North Korea         30
# North Macedonia     30
#                     ..
# Greenland           30
# Grenada             30
# Guam                30
# Guatemala           30
# Zimbabwe            30
# Name: Country/Territory, Length: 204, dtype: int64

# %%
plt.figure(figsize=(50,30),facecolor='lightblue')
sns.countplot(data[data.columns[2]], color = 'green')
plt.xlabel(data.columns[2],fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=25)
plt.show()

# %%
plt.figure(figsize=(50,30),facecolor='lightblue')
sns.countplot(data[data.columns[3]][:11], color = 'green')
plt.xlabel(data.columns[3],fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=25)
plt.show()

# %%
data.columns
# Out:
# Index(['Country/Territory', 'Code', 'Year', 'Meningitis',
#        'Alzheimer's Disease and Other Dementias', 'Parkinson's Disease',
#        'Nutritional Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis'],
#       dtype='object')

# %%
reason_list = data.columns[3:]

# %%
reason_list.shape
# Out:
# (31,)

# %%
data.columns
# Out:
# Index(['Country/Territory', 'Code', 'Year', 'Meningitis',
#        'Alzheimer's Disease and Other Dementias', 'Parkinson's Disease',
#        'Nutritional Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis'],
#       dtype='object')

# %%
data['Total death'] = data["Meningitis"] + data["Alzheimer's Disease and Other Dementias"] + data["Parkinson's Disease"] + data["Nutritional Deficiencies"]

# %%
data.head()
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# ...

# %%
country_Total_death = data.groupby("Country/Territory").sum()["Total death"].sort_values(ascending=False)

# %%
data.head()
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# ...

# %%
country_Total_death = data.groupby("Country/Territory").sum()["Total death"].sort_values(ascending=False)

# %%
country_Total_death
# Out:
# Country/Territory
# China            7980073
# India            7763906
# United States    4136973
# Japan            2999666
# Nigeria          2115492
#                   ...
# Tuvalu                84
# Palau                 75
# Nauru                 41
# Niue                  12
# Tokelau                0
# Name: Total death, Length: 204, dtype: int64

# %%
country_Total_death = data.groupby("Country/Territory").sum()["Total death"].sort_values(ascending=False)
plt.figure(figsize=(15,10),facecolor='lightblue')
sns.barplot(x=country_Total_death.values[0:11],y=country_Total_death.index[0:11])
plt.ylabel("")
plt.xlabel("Total # of death")
# Out:
# Text(0.5, 0, 'Total # of death')

# %%
country_Total_death_by_year = data.groupby("Year").sum()["Total death"].sort_values(ascending=False)
plt.figure(figsize=(15,10),facecolor='lightblue')
sns.barplot(x=country_Total_death_by_year.values[0:11],y=country_Total_death_by_year[0:11])
plt.ylabel("")
plt.xlabel("Total # of death by year")
# Out:
# Text(0.5, 0, 'Total # of death by year')

# %%
plt.figure(figsize=(15,10),facecolor='lightblue')
sns.barplot("Year","Total death",data = data)
plt.show()

# %%
data['Country/Territory'].nunique()
# Out:
# 204

# %%
data['Country/Territory'].unique()[0]
# Out:
# 'Afghanistan'

# %%
turkey_2017 = data[data['Country/Territory'] == "Turkey"].groupby("Year").sum().loc[2019].sort_values(ascending=False)
sns.barplot(x=turkey_2017.values[:10],y=turkey_2017.index[:10],orient="h")
# Out:
# <AxesSubplot:>

# %%
data1 = data.drop(columns = ['Total death'],axis =1)

# %%
Afghanistan_2017 = data1[data1['Country/Territory'] == "Afghanistan"].groupby("Year").sum().loc[2017].sort_values(ascending=False)
sns.barplot(x=Afghanistan_2017.values[:10],y=Afghanistan_2017.index[:10],orient="h")
# Out:
# <AxesSubplot:>

# %%
Afghanistan_2017 = data[data['Country/Territory'] == "Afghanistan"].groupby("Year").sum().loc[2017].sort_values(ascending=False)
Afghanistan_2017
# Out:
# Cardiovascular Diseases                       59553
# Neonatal Disorders                            23956
# Neoplasms                                     20111
# Lower Respiratory Infections                  19868
# Conflict and Terrorism                        19356
# Road Injuries                                  8013
# Chronic Respiratory Diseases                   6982
# Digestive Diseases                             6841
# Chronic Kidney Disease                         5419
# Diarrheal Diseases                             5328
# Total death                                    5297
# Interpersonal Violence                         5191
# Diabetes Mellitus                              4497
# Maternal Disorders                             4123
# Tuberculosis                                   3783
# Cirrhosis and Other Chronic Liver Diseases     3693
# Acute Hepatitis                                2046
# Alzheimer's Disease and Other Dementias        1728
# ...

# %%
country_Total_death1 = data.groupby("Year").sum()["Total death"].sort_values(ascending=False)
plt.figure(figsize=(15,10),facecolor='lightblue')
sns.barplot(x=country_Total_death1.index[0:11],y=country_Total_death1.values[0:11])
plt.ylabel("")
plt.xlabel("Total # of death by year")
# Out:
# Text(0.5, 0, 'Total # of death by year')

# %%
country_Total_death.index[0:10]
# Out:
# Index(['China', 'India', 'United States', 'Japan', 'Nigeria', 'Indonesia',
#        'Brazil', 'Ethiopia', 'Pakistan', 'Germany'],
#       dtype='object', name='Country/Territory')

# %%
China = data1[data1['Country/Territory'] == "China"].groupby("Year").sum().loc[2019].sort_values(ascending=False)
sns.barplot(x=China.values[:10],y=China.index[:10],orient="h")
# Out:
# <AxesSubplot:>

# %%
India = data1[data1['Country/Territory'] == "India"].groupby("Year").sum().loc[2019].sort_values(ascending=False)
sns.barplot(x=India.values[:10],y=India.index[:10],orient="h")
# Out:
# <AxesSubplot:>

# %%
Russia = data1[data1['Country/Territory'] == "Russia"].groupby("Year").sum().loc[2019].sort_values(ascending=False)
sns.barplot(x=Russia.values[:10],y=Russia.index[:10],orient="h")
# Out:
# <AxesSubplot:>

# %%
Indonesia = data1[data1['Country/Territory'] == "Indonesia"].groupby("Year").sum().loc[2019].sort_values(ascending=False)
sns.barplot(x=Indonesia.values[:10],y=Indonesia.index[:10],orient="h")
# Out:
# <AxesSubplot:>

# %%
Nigeria = data1[data1['Country/Territory'] == "Nigeria"].groupby("Year").sum().loc[2019].sort_values(ascending=False)
sns.barplot(x=Nigeria.values[:10],y=Nigeria.index[:10],orient="h")
# Out:
# <AxesSubplot:>

# %%
Pakistan = data1[data1['Country/Territory'] == "Pakistan"].groupby("Year").sum().loc[2019].sort_values(ascending=False)
sns.barplot(x=Pakistan.values[:10],y=Pakistan.index[:10],orient="h")
# Out:
# <AxesSubplot:>

# %%
Brazil = data1[data1['Country/Territory'] == "Brazil"].groupby("Year").sum().loc[2019].sort_values(ascending=False)
sns.barplot(x=Brazil.values[:10],y=Brazil.index[:10],orient="h")
# Out:
# <AxesSubplot:>

# %%
Japan = data1[data1['Country/Territory'] == "Japan"].groupby("Year").sum().loc[2019].sort_values(ascending=False)
sns.barplot(x=Japan.values[:10],y=Japan.index[:10],orient="h")
# Out:
# <AxesSubplot:>

# %%
Germany = data1[data1['Country/Territory'] == "Germany"].groupby("Year").sum().loc[2019].sort_values(ascending=False)
sns.barplot(x=Germany.values[:10],y=Germany.index[:10],orient="h")
# Out:
# <AxesSubplot:>
